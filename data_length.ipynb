# %%
import pandas as pd

# %%
data = pd.read_csv('./origin_llama2_when.csv')

# %%
data['length'] = data.caption.apply(len)
data['length'] = data['length'] // 10 *10

# %%
data['length'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='length'>
