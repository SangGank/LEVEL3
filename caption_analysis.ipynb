# %%
import pandas as pd

# %%
data = pd.read_csv('./genre_11_tempo_4.csv')
data = data[['caption','genre','tempo(category)','emotion']]
data
# data = data[~data.duplicated(['caption','genre','tempo(category)','emotion'])]
# Out:
#                                                 caption   genre  \
# 0     The melody is mellow and soothing, with a gent...    Rock
# 1     Elegant and sweeping orchestral melody with a ...     Pop
# 2     catchy and upbeat, featuring a memorable guita...    Rock
# 3     A catchy and memorable tune with a simple yet ...    Rock
# 4     The melody is catchy and memorable, with a ble...    Rock
# ...                                                 ...     ...
# 9966  catchy and memorable melody with a distinctive...     Pop
# 9967  catchy and upbeat, with a distinctive accordio...  Groove
# 9968  catchy and upbeat, with a memorable guitar rif...     Pop
# 9969  catchy and upbeat, featuring a memorable synth...    Rock
# 9970  The catchy and upbeat melody of this song feat...     Pop
#
#      tempo(category)     emotion
# 0            Allegro   nostalgia
# 1           Moderato   nostalgia
# 2           Moderato  excitement
# 3            Andante   nostalgia
# ...

# %%
duple = data[data.duplicated(['caption'])]['caption'].unique()
data[data['caption'].isin(duple)].sort_values(by='caption')
# data[data['caption'].isin(duple)].sort_values(by='caption').to_csv('./duplicate_data.csv',index = False, encoding='utf-8')
